# %% [markdown]
# <!-- PY-AI-ML-HEADER -->
# # 📘 Modules & Random Library
# ## 📝 Lec 02 Random Library
#
# > **Series:** Python for AI/ML &nbsp;|&nbsp; **Author:** Sriyut Singh &nbsp;|&nbsp; **Folder:** `04-modules-and-random`
#
# ---
# ### 👇 Code & Output Below

# %% [markdown]
# # shift+tab        ,this is used to get details
#
#
# # dir  ,this is used to know all code

# %%
import random

dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_Sequence',
#  '_Set',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_inst',
#  '_log',
#  '_os',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  '_warn',
#  'betavariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'normalvariate',
#  'paretovariate',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
#  'vonmisesvariate',
#  'weibullvariate']

# %%
x='hello world'

y=',i am a string'

# this is conenatination 
#add two variables in one
z=x+y

z
# Out:
# 'hello world,i am a string'

# %%
type(x)
# Out:
# str

# %%
type(y)
# Out:
# str

# %% [markdown]
# # print is a nonetype

# %%
a='sriyut'

b=' kumar'

c=a+b

c
# Out:
# 'sriyut kumar'

# %%
# this is called repeatation 

c*100
# Out:
# 'sriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumarsriyut kumars
# ...

# %%
# indexing

# indexing starts with 0

n='sriyut'

n[0]
# Out:
# 's'

# %%
n[1]
# Out:
# 'r'

# %%
n[2]
# Out:
# 'i'

# %%
n[3]
# Out:
# 'y'

# %%
a[0]
# Out:
# 's'

# %%
b[0]
# Out:
# ' '

# %%
a[-1]
# Out:
# 't'

# %%
a[-6]
# Out:
# 's'

# %%
b[-5]
# Out:
# 'k'

# %%
b[-1]
# Out:
# 'r'

# %%
b[-5]
# Out:
# 'k'

# %%
#if we want to know how much letter in our string ,, len

len(c)
# Out:
# 12

# %% [markdown]
# # our next task is slicing(do with net)
