# %% [markdown]
# <!-- PY-AI-ML-HEADER -->
# # 📘 Python Basics
# ## 📝 Lec 04 User Input If Else Pass
#
# > **Series:** Python for AI/ML &nbsp;|&nbsp; **Author:** Sriyut Singh &nbsp;|&nbsp; **Folder:** `01-python-basics`
#
# ---
# ### 👇 Code & Output Below

# %%
# USER INPUT

m=input('enter:')

print('m is:' +m)

type(m)
# Out:
# enter:m
# m is:m
# str

# %%
# IF-ELSE

a=20
b=40
if b > a:
    print('b is greater than a')
# Out:
# b is greater than a

# %%
# if....elif....statement

del(a)
del(b)

a=10
b=1
if a > b:
    print('a won')
elif b==a:
    print('tie')
# Out:
# a won

# %%
a=10
b=10
if a > b:
    print('a won')
elif b==a:
    print('tie')
# Out:
# tie

# %%
# else

a=10
b=10
if a > b:
    print('a won')
else:
    print('above is not true')
# Out:
# above is not true

# %%
g=int(input('write a number: '))

if g >= 90:
    print('A GRADE')
elif g >= 80:
    print('B GRADE')
elif g >= 70:
    print('C GRADE')
elif g >= 60:
    print('D GRADE')
else:
    print('fail')
# Out:
# write a number: 5
# fail

# %%
k=200
j=33
h=500
if  k > j and h > k:
    print('won')
# Out:
# won

# %%
c=40

if c > 10:
    print('above 10,',end="")
    if c > 20:
        print('also above 20!')
# Out:
# above 10,also above 20!

# %% [markdown]
# # Pass

# %%
o=33
i=200

if o>i:
    pass #pass statement
