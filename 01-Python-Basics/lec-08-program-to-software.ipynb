# %% [markdown]
# <!-- PY-AI-ML-HEADER -->
# # 📘 Python Basics
# ## 📝 Lec 08 Program To Software
#
# > **Series:** Python for AI/ML &nbsp;|&nbsp; **Author:** Sriyut Singh &nbsp;|&nbsp; **Folder:** `01-python-basics`
#
# ---
# ### 👇 Code & Output Below

# %%
#pyinstaller.exe --onefile -w filename.py


'''The command written above is used to convert an python file to an exe file and the above code is to be entered in cmd with the file details you want to change'''
# Out:
# 'The command written above is used to convert an python file to an exe file and the above code is to be entered in cmd with the file details you want to change'
