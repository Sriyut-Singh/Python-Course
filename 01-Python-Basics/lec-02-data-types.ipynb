# %% [markdown]
# <!-- PY-AI-ML-HEADER -->
# # 📘 Python Basics
# ## 📝 Lec 02 Data Types
#
# > **Series:** Python for AI/ML &nbsp;|&nbsp; **Author:** Sriyut Singh &nbsp;|&nbsp; **Folder:** `01-python-basics`
#
# ---
# ### 👇 Code & Output Below

# %%
#there are types of data types
#1.immutable    2.mmutable

# %%
#type casting

a=10

type(a)
# Out:
# int

# %%
b=str(a)

type(b)
# Out:
# str

# %%
c=complex(a)

type(c)
# Out:
# complex

# %%
#if we change string to number it should be a numeric number

int(c)

#we cant convert any complex number to integer or float but can be converted to string
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-6ed89a556987> in <module>
#       1 #if we change string to number it should be a numeric number
#       2
# ----> 3 int(c)
#       4
#       5 #we cant convert any complex number to integer or float but can be converted to string
#
# TypeError: can't convert complex to int

# %%
#random number

import random

print(random.randrange(1,11,3))#1 included,but last no. is exculeded

print(random.random())

print(random.randint(1,10,))#first and last number both are included
# Out:
# 10
# 0.37733830043768946
# 8

# %%
s=input('enter your name: ')

print('Your name is',s)
# Out:
# enter your name: Sriyut
# Your name is Sriyut

# %% [markdown]
# # Random library test

# %%
import random

print(random.randrange(1,11))

print(random.random())

print(random.randint(1,10))

print(input('ENTER YOUR NAME: '))
# Out:
# 6
# 0.22049533846491742
# 6
# ENTER YOUR NAME: Sriyut
# Sriyut

# %% [markdown]
# # Test done

# %% [markdown]
# # REVISION CLASS

# %%
a=10;b=20

print(a);print(b)
# Out:
# 10
# 20

# %%
#indentation
a=3
if a>2:
    print('hello world')
# Out:
# hello world

# %%
#COMMENT

# %%
# TOKEN 

#key words are not used in variables



2<5 and 5>2

2>5 or 5>2

#not reverses the answer
# Out:
# True

# %%
a=10

type(a)
# Out:
# int

# %%
id(a)
# Out:
# 140735093286976

# %%
a='hello'

id(a)
# Out:
# 299528947248

# %%
b=[1,2,4,5]

id(b)
# Out:
# 299524444864

# %%
#changing the value
b[2]=12

print(b)

id(b)
# Out:
# [1, 2, 12, 5]
# 299524444864

# %%
x=1

y=2.8

z=1j

# %%
type(x)
# Out:
# int

# %%
type(y)
# Out:
# float

# %%
type(z)
# Out:
# complex

# %%
y=int(y)

type(y)
# Out:
# int

# %%
z=str(z)

type(z)
# Out:
# str

# %%
z=complex(z)
print(z)
type(z)
# Out:
# 1j
# complex

# %%
x=float(x)

x
# Out:
# 1.0

# %%
n='s',1,2

type(n)
# Out:
# tuple
