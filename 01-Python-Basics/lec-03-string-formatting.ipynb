# %% [markdown]
# <!-- PY-AI-ML-HEADER -->
# # 📘 Python Basics
# ## 📝 Lec 03 String Formatting
#
# > **Series:** Python for AI/ML &nbsp;|&nbsp; **Author:** Sriyut Singh &nbsp;|&nbsp; **Folder:** `01-python-basics`
#
# ---
# ### 👇 Code & Output Below

# %%
'sriyut {}'.format('kumar')
# Out:
# 'sriyut kumar'

# %% [markdown]
# # FAST STRING

# %%
name='sriyut'
age= 12
print(f"name:{name}and age:{age}")
# Out:
# name:sriyutand age:12

# %% [markdown]
# # Escape characters

# %%
print('i am \'a\'string')
# Out:
# i am 'a'string

# %%
print('my name is \n sriyut')
# Out:
# my name is
#  sriyut

# %%
print('sriyut\t sriyut')
# Out:
# sriyut	 sriyut

# %%
print('name=sriyut\n age=12\n class=7')
# Out:
# name=sriyut
#  age=12
#  class=7

# %%
dir(name)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
name,age='sonakshi',24
address='arjunagar'
print(f' name: {name}\n age: {age}\n address:{address}')
# Out:
#  name: sonakshi
#  age: 24
#  address:arjunagar

# %%
name,age='sonakshi',24
address='arjunagar'
print(' name: \n age: \n address:')
# Out:
#  name:
#  age:
#  address:

# %%
#  Location and counting 

s='hello world concatenate me'

s.count('e')
# Out:
# 4

# %%
s.find('o')
# Out:
# 4

# %%
s.center(40,'-')
# Out:
# '-------hello world concatenate me-------'

# %%
#   is check

m='hello'

m.isalnum()
# Out:
# True

# %%
m.isalpha()
# Out:
# True

# %%
m.istitle()
# Out:
# False

# %%
m.endswith('o')
# Out:
# True

# %%
# BUILT -in reg.expression

s.split('e')
# Out:
# ['h', 'llo world concat', 'nat', ' m', '']

# %%
s.partition('l')
# Out:
# ('he', 'l', 'lo world concatenate me')

# %%
cstr = "I love Python"
   
# Printing the center aligned  
# string with fillchr 
print ("Center aligned string with fillchr: ") 
print (cstr.center(100, 'z')) 
 
# Printing the left aligned  
# string with "-" padding  
print ("The left aligned string is : ") 
print (cstr.ljust(40, '-'))
 
# Printing the right aligned string 
# with "-" padding  
print ("The right aligned string is : ") 
print (cstr.rjust(40, '-'))
# Out:
# Center aligned string with fillchr:
# zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzI love Pythonzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# The left aligned string is :
# I love Python---------------------------
# The right aligned string is :
# ---------------------------I love Python

# %%
#we have to perform these function
'''capitalize',
 'casefold',
 'center',
 'count',
 'encode',
 'endswith',
 'expandtabs',
 'find',
 'format',
 'format_map',
 'index',
 'isalnum',
 'isalpha',
 'isascii',
 'isdecimal',
 'isdigit',
 'isidentifier',
 'islower',
 'isnumeric',
 'isprintable',
 'isspace',
 'istitle',
 'isupper',
 'join',
 'ljust',
 'lower',
 'lstrip',
 'maketrans',
 'partition',
 'replace',
 'rfind',
 'rindex',
 'rjust',
 'rpartition',
 'rsplit',
 'rstrip',
 'split',
 'splitlines',
 'startswith',
 'strip',
 'swapcase'''
# Out:
# "capitalize',\n 'casefold',\n 'center',\n 'count',\n 'encode',\n 'endswith',\n 'expandtabs',\n 'find',\n 'format',\n 'format_map',\n 'index',\n 'isalnum',\n 'isalpha',\n 'isascii',\n 'isdecimal',\n 'isdigit',\n 'isidentifier',\n 'islower',\n 'isnumeric',\n 'isprintable',\n 'isspace',\n 'istitle',\n 'isupper',\n 'join',\n 'ljust',\n 'lower',\n 'lstrip',\n 'maketrans',\n 'partition',\n 'replace',\n 'rfind',\n 'rindex',\n 'rjust',\n 'rpartition',\n 'rsplit',\n 'rstrip',\n 'split',\n 'splitlines',\n 'startswith',\n 'strip',\n 'swapcase"
