# %% [markdown]
# <!-- PY-AI-ML-HEADER -->
# # 📘 Python Basics
# ## 📝 Lec 01 Python Start
#
# > **Series:** Python for AI/ML &nbsp;|&nbsp; **Author:** Sriyut Singh &nbsp;|&nbsp; **Folder:** `01-python-basics`
#
# ---
# ### 👇 Code & Output Below

# %% [markdown]
# # SIMPLE PYTHON

# %%
x = 5
type(x)
# Out:
# int

# %%
x=str(x)
type(x)
# Out:
# str

# %%
s = 3
u = 4
a = (s+u)
print(a)
type(a)
# Out:
# 7
# int

# %%
y=' john'
print(x+y)
# Out:
# 5 john

# %%
y='sriyut '
x=' kumar'
print(y+x)
# Out:
# sriyut  kumar

# %%
y='sriyut '
x=' kumar'
print(y*8+x*8)
# Out:
# sriyut sriyut sriyut sriyut sriyut sriyut sriyut sriyut  kumar kumar kumar kumar kumar kumar kumar kumar

# %%
y='sriyut '
x=' kumar'
print(y+x*8)
# Out:
# sriyut  kumar kumar kumar kumar kumar kumar kumar kumar

# %%
type(x)
# Out:
# str

# %%
type(y)
# Out:
# str

# %%
a='sriyut '
b='kumar '
c='singh '
print(a+b+c)
# Out:
# sriyut kumar singh

# %%
pow(3,2)
# Out:
# 9

# %%
(1+5)*3
# Out:
# 18

# %%
test="hello world"

id(test)
# Out:
# 891908601968

# %%
print('hello \n how')
print("this is a \
python class")
# Out:
# hello
#  how
# this is a python class

# %%
print(1+2*3)
# Out:
# 7

# %%
a=100;b=230;c=a+b

print(c)
# Out:
# 330

# %%
print(a)

print(b)

print(c)
# Out:
# 100
# 230
# 330

# %%
x=10;y=30;
print(x);print(y)
# Out:
# 10
# 30

# %%
while True:
    print('hello')
#it will not stop#this is using of if
a=1
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# ...

# %%
#this is using of if
a=1
if a>0:
    print('hello')
# Out:
# hello

# %%
'''this is a new form to do comment'''
# Out:
# 'this is a new form to do comment'

# %%
a=2
a>3
# Out:
# False

# %%
a='python'
type(a)
# Out:
# str

# %%
2**3
# Out:
# 8

# %% [markdown]
# # HOME WORK

# %%
#THIS IS ADDITION
2+3
# Out:
# 5

# %%
#THIS IS MULTIPLICATION
2*3
# Out:
# 6

# %%
#THIS IS DIVISION
3/2
# Out:
# 1.5

# %%
# THIS IS SUBTRACTION
3-2
# Out:
# 1

# %%
#THIS IS POWER
2**3
# Out:
# 8

# %%
#THIS IS FLOOR DIVISION
3//2
# Out:
# 1

# %%
#THIS IS REMAINDER
2%3
# Out:
# 2

# %% [markdown]
# # H.W DONE

# %%
#an (=) sign is the first arthemithic operator

#when WE use (=) sign with any operator the operator becommes assignment operator

#we always use (=) sign after operator

#for example

a=2

# %%
#now we are learning comparision operators
#1.==  equal
#2.!=  not equal
#3.<   lessthan
#4.>   greaterthan
#5.<=  lessthan or equal
#6.>=  greater or equal

a += 5

print(a)
# Out:
# 7

# %%
#to delete we will use del
del(a)

a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-5532a9b65de6> in <module>
#       2 del(a)
#       3
# ----> 4 a
#
# NameError: name 'a' is not defined

# %%
a=4

b=4

a==b
# Out:
# True

# %%
a!=b
# Out:
# False

# %%
2>1 and 2>1
# Out:
# True

# %%
#this is membership operator

x='a','b'

print('a'not in x)

print('a'in x)

print('c'not in x)
# Out:
# False
# True
# True

# %%
#this is identity operator

x=10

z=x

print(x is z)
# Out:
# True

# %%
#this is bitwise operator

i=10

id(i)

h=i

id(h)
# Out:
# 140735093286976

# %%
#these are data types

print(type(h))
# Out:
# <class 'int'>

# %%
#ASSIGNMENT OPERATOR

s=5

s += 5

print(s)
# Out:
# 10

# %%
#COMPARISION OPERATOR

r=2

s!=r

s>r

r<=s
# Out:
# True

# %%
#MEMBERSHIP OPERATOR

i='s','r'

print('s' in i)

print('i' not in i)
# Out:
# True
# True

# %%
#IDENTITY OPERATOR

y=10

u=y

print(y is u)
# Out:
# True

# %%
#DATA TYPE OPERATOR

t='sriyut'

print(type(t))
# Out:
# <class 'str'>

# %%
#BITWISE OPERATOR

kumar=100

singh=kumar

id(kumar)

id(singh)
# Out:
# 140735093289856
