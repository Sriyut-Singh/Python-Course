# %% [markdown]
# <!-- PY-AI-ML-HEADER -->
# # 📘 Practice & Assignments
# ## 📝 Lec 06 Practice File 5
#
# > **Series:** Python for AI/ML &nbsp;|&nbsp; **Author:** Sriyut Singh &nbsp;|&nbsp; **Folder:** `10-practice-and-assignments`
#
# ---
# ### 👇 Code & Output Below

# %% [markdown]
# # Using numpy
# numpy is made for calculation only

# %%
import numpy

# %%
dir(numpy)
# Out:
# ['ALLOW_THREADS',
#  'AxisError',
#  'BUFSIZE',
#  'CLIP',
#  'ComplexWarning',
#  'DataSource',
#  'ERR_CALL',
#  'ERR_DEFAULT',
#  'ERR_IGNORE',
#  'ERR_LOG',
#  'ERR_PRINT',
#  'ERR_RAISE',
#  'ERR_WARN',
#  'FLOATING_POINT_SUPPORT',
#  'FPE_DIVIDEBYZERO',
#  'FPE_INVALID',
#  'FPE_OVERFLOW',
#  'FPE_UNDERFLOW',
#  'False_',
#  'Inf',
#  'Infinity',
#  'MAXDIMS',
#  'MAY_SHARE_BOUNDS',
#  'MAY_SHARE_EXACT',
#  'MachAr',
#  'ModuleDeprecationWarning',
#  'NAN',
#  'NINF',
#  'NZERO',
#  'NaN',
#  'PINF',
#  'PZERO',
#  'RAISE',
#  'RankWarning',
#  'SHIFT_DIVIDEBYZERO',
#  'SHIFT_INVALID',
#  'SHIFT_OVERFLOW',
#  'SHIFT_UNDERFLOW',
#  'ScalarType',
#  'Tester',
#  'TooHardError',
#  'True_',
#  'UFUNC_BUFSIZE_DEFAULT',
#  'UFUNC_PYVALS_NAME',
#  'VisibleDeprecationWarning',
#  'WRAP',
#  '_NoValue',
#  '_UFUNC_API',
#  '__NUMPY_SETUP__',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__config__',
#  '__dir__',
#  '__doc__',
#  '__file__',
#  '__getattr__',
# ...

# %%
a = numpy.arange(100) 
print(a**2)
# Out:
# [   0    1    4    9   16   25   36   49   64   81  100  121  144  169
#   196  225  256  289  324  361  400  441  484  529  576  625  676  729
#   784  841  900  961 1024 1089 1156 1225 1296 1369 1444 1521 1600 1681
#  1764 1849 1936 2025 2116 2209 2304 2401 2500 2601 2704 2809 2916 3025
#  3136 3249 3364 3481 3600 3721 3844 3969 4096 4225 4356 4489 4624 4761
#  4900 5041 5184 5329 5476 5625 5776 5929 6084 6241 6400 6561 6724 6889
#  7056 7225 7396 7569 7744 7921 8100 8281 8464 8649 8836 9025 9216 9409
#  9604 9801]

# %%
import numpy as np

# %% [markdown]
# ### abs returns the value in only numbers if the number is negative it don't show it as negative

# %%
#checking the abs module
a = 100-1000
#so,if we subtract 1000 from 100 we will get -900 but see the out put
print(abs(a))
# Out:
# 900

# %% [markdown]
# ###### see  that  the abs shows the number only not the minus sign

# %%
#if we dont write the abs see what happens
#coping the same code
a = 100-1000
#so,if we subtract 1000 from 100 we will get -900 but see the out put
print(a)#not written abs module
# Out:
# -900

# %% [markdown]
# ###### as you can see the answer is ni the minus sign

# %%
a = np.add(100,300)

# %%
print(a)
# Out:
# 400

# %%
b = np.all(a)#Test whether all array elements along a given axis evaluate to True.
print(b)
# Out:
# True

# %% [markdown]
# ##### Making two dimentions array

# %%
a= np.array(['sriyut','sahho',2,3])#making two dimentions array
print(a)
#you will see the two different array in the output
# Out:
# ['sriyut' 'sahho' '2' '3']

# %% [markdown]
# #### Not taking the string and the integer in one array

# %%
#i dont know why it shows error in some files an run in other files

# %%
a=np.array([[1,2],[3,4]])
print(a)
# Out:
# [[1 2]
#  [3 4]]

# %% [markdown]
# ###### as you can see it is showing the output in two different lines

# %%
a = np.lcm(12,99)

# %%
print(a)
# Out:
# 396

# %% [markdown]
# ### It also have the lcm function
# it is really made for math

# %%
a = np.absolute([12,4])

# %% [markdown]
# ###### the code above Calculate the absolute value element-wise.

# %%
print(a)
# Out:
# [12  4]

# %%
a = np.half(22)
print(a)
# Out:
# 22.0

# %% [markdown]
# ###### welcome to the average game

# %%
you='You can only write four numbers \nAnd check the average of those number'
print(you)
a=int(input('write the number: '))
b=int(input('write the number: '))
c=int(input('write the number: '))
d=int(input('write the number: '))
calculate='Now we are going to calculate the averge of all the number'
print(calculate)
e = a+b+c+d/4
print('this is the average of those number',e)
# Out:
# You can only write four numbers
# And check the average of those number
# write the number: 20
# write the number: 22
# write the number: 55
# write the number: 66
# Now we are going to calculate the averge of all the number
# this is the average of those number 113.5
