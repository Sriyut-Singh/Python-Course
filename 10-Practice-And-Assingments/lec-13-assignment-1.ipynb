# %% [markdown]
# <!-- PY-AI-ML-HEADER -->
# # 📘 Practice & Assignments
# ## 📝 Lec 13 Assignment 1
#
# > **Series:** Python for AI/ML &nbsp;|&nbsp; **Author:** Sriyut Singh &nbsp;|&nbsp; **Folder:** `10-practice-and-assignments`
#
# ---
# ### 👇 Code & Output Below

# %% [markdown]
# # FINDING AREA OF CIRCLE

# %%
r=int(input('write a number: '))
# Out:
# write a number: 12

# %%
a=(22/7)*(r)**(2)
print('THE AREA OF CIRCLE IS=',a)
# Out:
# THE AREA OF CIRCLE IS= 452.57142857142856

# %% [markdown]
# # STRING (NON-NEGATIVE)

# %%
x=input('write your name: ')
# Out:
# write your name:  sriyut

# %%
print(x*10)
# Out:
#  sriyut  sriyut  sriyut  sriyut  sriyut  sriyut  sriyut  sriyut  sriyut  sriyut

# %% [markdown]
# # ASSINGMENT OPERATOR

# %%
b=int(input('write a number: '))
# Out:
# write a number: 24

# %%
b += 5
print(b)
# Out:
# 29

# %%
b -= 4
print(b)
# Out:
# 25

# %%
b *= 3
print(b)
# Out:
# 75

# %%
b **= 5
print(b)
# Out:
# 2373046875

# %% [markdown]
# # NAME AND AGE QUESTION

# %%
m=input('write your name: ')
y=input('write your age: ')
h=input('write your adress: ')
# Out:
# write your name: sriyut
# write your age: 12
# write your adress: I.P EXTENTION,DELHI

# %%
print('name=',m)
print('age=',y)
print('ADRESS=',h)
# Out:
# name= sriyut
# age= 12
# ADRESS= I.P EXTENTION,DELHI

# %% [markdown]
# # PERIMETER OF A TRIANGLE

# %%
r=int(input('write a number: '))
# Out:
# write a number: 9

# %%
w=int(input('write a number: '))
# Out:
# write a number: 19

# %%
e=int(input('write a number: '))
# Out:
# write a number: 36

# %%
k=(r+w+e)
print('PERIMETER OF TRIANGLE IS=',k)
# Out:
# PERIMETER OF TRIANGLE IS= 64

# %% [markdown]
# # EVEN /ODD QUESTION
