# %% [markdown]
# <!-- PY-AI-ML-HEADER -->
# # 📘 Practice & Assignments
# ## 📝 Lec 11 Home Assignment 3
#
# > **Series:** Python for AI/ML &nbsp;|&nbsp; **Author:** Sriyut Singh &nbsp;|&nbsp; **Folder:** `10-practice-and-assignments`
#
# ---
# ### 👇 Code & Output Below

# %% [markdown]
# # English     60        100      C

# %% [markdown]
# # Percentage = 78%

# %%
a=int(input('english marks: '))
b=int(input('maths marks: '))
c=int(input('science marks: '))
d=int(input('hindi marks: '))
e=int(input('social science marks: '))
print(a)
print(b)
print(c)
print(d)
print(e)
# Out:
# english marks: 40
# maths marks: 70
# science marks: 85
# hindi marks: 65
# social science marks: 70
# 40
# 70
# 85
# 65
# 70

# %%
if a>= 90:
    print('A GRADE')
elif a<= 90:
    print('B GRADE')
if b>=90:
    print('A GRADE')
elif b<=90:
    print('B GRADE')
if c>=90:
    print('A GRADE')
elif c<=90:
    print('B GRADE')
if d>=90:
    print('A GRADE')
elif d<=90:
    print('B GRADE')
if e>=90:
    print('A GRADE')
elif e<=90:
    print('B GRADE')
# Out:
# B GRADE
# B GRADE
# B GRADE
# B GRADE
# B GRADE

# %%
print('your marks of english is =',a)
print('your marks of maths is =',b)
print('your marks of science is =',c)
print('your marks of hindi is =',d)
print('your marks of social science is =',e)
print('your persentage =',g)
# Out:
# your marks of english is = 40
# your marks of maths is = 70
# your marks of science is = 85
# your marks of hindi is = 65
# your marks of social science is = 70
# your persentage = 66.0

# %%
f=a+b+c+d+e
f
# Out:
# 330

# %%
f/500
# Out:
# 0.66

# %%
g=(f/500)*100
g
# Out:
# 66.0
