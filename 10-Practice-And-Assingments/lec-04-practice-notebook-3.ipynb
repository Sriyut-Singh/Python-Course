# %% [markdown]
# <!-- PY-AI-ML-HEADER -->
# # 📘 Practice & Assignments
# ## 📝 Lec 04 Practice Notebook 3
#
# > **Series:** Python for AI/ML &nbsp;|&nbsp; **Author:** Sriyut Singh &nbsp;|&nbsp; **Folder:** `10-practice-and-assignments`
#
# ---
# ### 👇 Code & Output Below

# %%
print('Hello world')
# Out:
# Hello world

# %%
def sriyut(s,i,r):
    print('Writing the name of members of the family....')
    return 'FATHER',r,'MOTHER',i,'SON',s
s=input('write your name: ')
i=input('write your mother name: ')
r=input('write your father name: ')
sriyut(s,i,r)
y=s+i+r
e='aeiou'
g='friend'
c=0
for i in y:
    if i in e:
        c=c+5
    elif i in g:
        c=c+10
    else:
        c=c+1
print('your score is',c)
# Out:
# write your name: sriyut
# write your mother name: sweety
# write your father name: rupesh
# Writing the name of members of the family....

# %%
a=input('write your name: ')
b=input('write your friend name: ')
d=a + b
e='aeiou'
g='friend'
f=len(d)
c=0
for i in d:
    if i in e:
        c=c+5
    elif i in g:
        c=c+10
    else:
        c=c+1
print('your score is',c)

# %%
print('WELCOME TO RECTANGLE AND SQUARE AREA AND PERIMETER PROGRAM')
print('FIRST YOU HAVE TO SELECT EITHER YOUR SHAPE IS A RECTANGLE OR SQUARE')
print('FOR CHOSING THE RECTANGLE WRITE 1 AND FOR SQUARE WRITE 2')
a=int(input('WRITE THE SHAPE OF YOUR DIAGRAM (BY NUMBERS): '))
if a==1 or a==2:
    b=float(input('WRITE THE LENGTH OF THE SHAPE: '))
    c=float(input('WRITE THE BREADTH OF THE SHAPE: '))
    i=input('WRITE THE UNIT OF YOUR LENGTH AND BREADTH: ')
    print('WRITE WHAT DO YOU WANT AREA OR PERIMETER')
    print('FOR AREA WRITE 1 AND FOR PEIMETER WRITE 2')
    d=int(input('WRITE WHEATHER YOU WANT AREA OR PERIMETER: '))
    if a==1 and d==1:
        e=b*c
        print(e,i,'.sq')
    if a==1 and d==2:
        f=2*(b+c)
        print(f,i)
    if a==2 and d==1:
        g=b*c
        print(g,i,'.sq')
    if a==2 and d==2:
        h=4*b 
        print(h,i)
    if a==1:
        num=8
        for i in range(num):
            for j in range(num):
                if i==0 or i==num-1 or j==0 or j==num-1:
                    print('*',end='')
                else:
                    print(' ',end='')
            print()
    if a==2:
        num=6
        for i in range(num):
            for j in range(num):
                if i==0 or i==num-1 or j==0 or j==num-1:
                    print('*',end=' ')
                else:
                    print(' ',end=' ')
            print()
print('THANK YOU FOR USING THE PROGRAM')
# Out:
# WELCOME TO RECTANGLE AND SQUARE AREA AND PERIMETER PROGRAM
# FIRST YOU HAVE TO SELECT EITHER YOUR SHAPE IS A RECTANGLE OR SQUARE
# FOR CHOSING THE RECTANGLE WRITE 1 AND FOR SQUARE WRITE 2
# WRITE THE SHAPE OF YOUR DIAGRAM (BY NUMBERS): 2
# WRITE THE LENGTH OF THE SHAPE: 6
# WRITE THE BREADTH OF THE SHAPE: 6
# WRITE THE UNIT OF YOUR LENGTH AND BREADTH: m
# WRITE WHAT DO YOU WANT AREA OR PERIMETER
# FOR AREA WRITE 1 AND FOR PEIMETER WRITE 2
# WRITE WHEATHER YOU WANT AREA OR PERIMETER: 1
# 36.0 m .sq
# * * * * * *
# *         *
# *         *
# *         *
# *         *
# * * * * * *
# THANK YOU FOR USING THE PROGRAM
