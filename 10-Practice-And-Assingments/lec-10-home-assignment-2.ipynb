# %% [markdown]
# <!-- PY-AI-ML-HEADER -->
# # 📘 Practice & Assignments
# ## 📝 Lec 10 Home Assignment 2
#
# > **Series:** Python for AI/ML &nbsp;|&nbsp; **Author:** Sriyut Singh &nbsp;|&nbsp; **Folder:** `10-practice-and-assignments`
#
# ---
# ### 👇 Code & Output Below

# %% [markdown]
# # print your details using .format method ?

# %% [markdown]
# # like name ,age, address etc

# %% [markdown]
# # with variable , without variable,  with numbers of string

# %%
s='my name is {}'.format('SRIYUT')
r='my age is {}'.format('12')
i='my adress is {}'.format('I.P EXTENTION,DELHI')
print(s)
print(r)
print(i)
# Out:
# my name is SRIYUT
# my age is 12
# my adress is I.P EXTENTION,DELHI

# %%
'my name is {}'.format('SRIYUT')
# Out:
# 'my name is SRIYUT'

# %%
'my age is {}'.format('12')
# Out:
# 'my age is 12'

# %%
'my adress is {}'.format('I.P EXTENTION,DELHI')
# Out:
# 'my adress is I.P EXTENTION,DELHI'

# %%
'i am in the world of python {}'.format ('known as pythonista')
# Out:
# 'i am in the world of python known as pythonista'

# %%
s.upper()
# Out:
# 'MY NAME IS SRIYUT'

# %%
r.upper()
# Out:
# 'MY AGE IS 12'

# %%
i.upper()
# Out:
# 'MY ADRESS IS I.P EXTENTION,DELHI'

# %%
#we have to perform these function
'''capitalize',
 'casefold',
 'center',
 'count',
 'encode',
 'endswith',
 'expandtabs',
 'find',
 'format',
 'format_map',
 'index',
 'isalnum',
 'isalpha',
 'isascii',
 'isdecimal',
 'isdigit',
 'isidentifier',
 'islower',
 'isnumeric',
 'isprintable',
 'isspace',
 'istitle',
 'isupper',
 'join',
 'ljust',
 'lower',
 'lstrip',
 'maketrans',
 'partition',
 'replace',
 'rfind',
 'rindex',
 'rjust',
 'rpartition',
 'rsplit',
 'rstrip',
 'split',
 'splitlines',
 'startswith',
 'strip',
 'swapcase''',
# Out:
# ("capitalize',\n 'casefold',\n 'center',\n 'count',\n 'encode',\n 'endswith',\n 'expandtabs',\n 'find',\n 'format',\n 'format_map',\n 'index',\n 'isalnum',\n 'isalpha',\n 'isascii',\n 'isdecimal',\n 'isdigit',\n 'isidentifier',\n 'islower',\n 'isnumeric',\n 'isprintable',\n 'isspace',\n 'istitle',\n 'isupper',\n 'join',\n 'ljust',\n 'lower',\n 'lstrip',\n 'maketrans',\n 'partition',\n 'replace',\n 'rfind',\n 'rindex',\n 'rjust',\n 'rpartition',\n 'rsplit',\n 'rstrip',\n 'split',\n 'splitlines',\n 'startswith',\n 'strip',\n 'swapcase",)

# %%
s.capitalize()
# Out:
# 'My name is sriyut'

# %%
s.casefold()
# Out:
# 'my name is sriyut'

# %%
s.center(40,"-")
# Out:
# '-----------my name is SRIYUT------------'

# %%
s.count('s')
# Out:
# 1

# %%
s.encode()
# Out:
# b'my name is SRIYUT'

# %%
s.endswith('T')
# Out:
# True

# %%
s.expandtabs()
# Out:
# 'my name is SRIYUT'

# %%
s.find('s')
# Out:
# 9

# %%
s.format()
# Out:
# 'my name is SRIYUT'

# %%
s.format_map('s')
# Out:
# 'my name is SRIYUT'

# %%
s.index('s')
# Out:
# 9

# %%
s.isalnum()
# Out:
# False

# %%
s.isalpha()
# Out:
# False

# %%
s.isascii()
# Out:
# True

# %%
s.isdecimal()
# Out:
# False

# %%
s.isdigit()
# Out:
# False

# %%
s.isidentifier()
# Out:
# False

# %%
s.islower()
# Out:
# False

# %%
s.isnumeric()
# Out:
# False

# %%
s.isprintable()
# Out:
# True

# %%
s.isspace()
# Out:
# False

# %%
s.istitle()
# Out:
# False

# %%
s.isupper()
# Out:
# False

# %%
s.join('king')
# Out:
# 'kmy name is SRIYUTimy name is SRIYUTnmy name is SRIYUTg'

# %%
s.ljust(1)
# Out:
# 'my name is SRIYUT'

# %%
s.lower()
# Out:
# 'my name is sriyut'

# %%
s.lstrip()
# Out:
# 'my name is SRIYUT'

# %%
s.maketrans('s' ,'r')
# Out:
# {115: 114}

# %%
s.partition('s')
# Out:
# ('my name i', 's', ' SRIYUT')

# %%
s.replace('is','was')
# Out:
# 'my name was SRIYUT'

# %%
s.rfind('s')
# Out:
# 9

# %%
s.rindex('s')
# Out:
# 9

# %%
s.rjust(1)
# Out:
# 'my name is SRIYUT'

# %%
s.rpartition('s')
# Out:
# ('my name i', 's', ' SRIYUT')

# %%
s.rsplit()
# Out:
# ['my', 'name', 'is', 'SRIYUT']

# %%
s.rstrip()
# Out:
# 'my name is SRIYUT'

# %%
s.split()
# Out:
# ['my', 'name', 'is', 'SRIYUT']

# %%
s.splitlines()
# Out:
# ['my name is SRIYUT']

# %%
s.startswith('king ')
# Out:
# False

# %%
s.strip()
# Out:
# 'my name is SRIYUT'

# %%
s.swapcase()
# Out:
# 'MY NAME IS sriyut'

# %%
s.upper()
# Out:
# 'MY NAME IS SRIYUT'

# %%
d=['apple','mango']

# %%
d.join('banana')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-e64e3f7556c4> in <module>
# ----> 1 d.join('banana')
#
# AttributeError: 'list' object has no attribute 'join'

# %%
e='-'

# %%
e=e.join(d)
e
# Out:
# 'appleapple-mangomango'

# %%
s = "-"
seq = ("a", "b", "c") # This is sequence of strings.
print (s.join( seq ))
# Out:
# a-b-c
