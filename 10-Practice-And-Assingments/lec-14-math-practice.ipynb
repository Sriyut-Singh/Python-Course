# %% [markdown]
# <!-- PY-AI-ML-HEADER -->
# # 📘 Practice & Assignments
# ## 📝 Lec 14 Math Practice
#
# > **Series:** Python for AI/ML &nbsp;|&nbsp; **Author:** Sriyut Singh &nbsp;|&nbsp; **Folder:** `10-practice-and-assignments`
#
# ---
# ### 👇 Code & Output Below

# %%
#sum of 3 consciutive multiple of 11 is 363.

# %%
a=363
for i in range(1,100):
    b=11*i
    print(b)
# Out:
# 11
# 22
# 33
# 44
# 55
# 66
# 77
# 88
# 99
# 110
# 121
# 132
# 143
# 154
# 165
# 176
# 187
# 198
# 209
# 220
# 231
# 242
# 253
# 264
# 275
# 286
# 297
# 308
# 319
# 330
# 341
# 352
# 363
# 374
# 385
# 396
# 407
# 418
# 429
# 440
# 451
# 462
# 473
# 484
# 495
# 506
# 517
# 528
# 539
# 550
# 561
# 572
# 583
# 594
# 605
# 616
# 627
# 638
# 649
# 660
# 671
# 682
# 693
# 704
# 715
# 726
# 737
# 748
# 759
# 770
# 781
# 792
# 803
# 814
# 825
# 836
# 847
# 858
# 869
# 880
# 891
# 902
# 913
# 924
# 935
# 946
# 957
# 968
# 979
# 990
# 1001
# 1012
# 1023
# 1034
# 1045
# 1056
# 1067
# 1078
# 1089

# %%
363/3
# Out:
# 121.0

# %%
110+121+132
# Out:
# 363

# %%
#sum of 2 number is 95 if 1 execdes the other by 15

# %%
a=95
for i in range(1):
        b=a-15
        b=b/2
        print('your first number is : ',b)
        b=b+15
        print('your second number is : ',b)
# Out:
# your first number is :  40.0
# your second number is :  55.0
