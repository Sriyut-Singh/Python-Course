# %% [markdown]
# <!-- PY-AI-ML-HEADER -->
# # 📘 Practice & Assignments
# ## 📝 Lec 01 Practice 1
#
# > **Series:** Python for AI/ML &nbsp;|&nbsp; **Author:** Sriyut Singh &nbsp;|&nbsp; **Folder:** `10-practice-and-assignments`
#
# ---
# ### 👇 Code & Output Below

# %%
num=int(input('enter the number for rows and column'))
for i in range(num):
    for j in range(num):
        if i==0 or i==num-1 or j==0 or j==num-1:
            print('*',end='')
        else:
            print(' ',end='')
    print()
# Out:
# enter the number for rows and column 10
# **********
# *        *
# *        *
# *        *
# *        *
# *        *
# *        *
# *        *
# *        *
# **********

# %%
num=int(input('enter the number of rows and column: '))
n_list=[[0 for x in range(num)]for y in range(num)]
n=i
low=0
high=num-1
count=int((num+1)/2)
for i in range(count):
    for j in range(low,high+1):
        n_list[i][j]=n
        n=n+1
    for j in range(low+1,high+1):
        n_list[j][high]=n
        n=n+1
    for j in range(high-1,low-1,-1):
        n_list[high][j]=n
        n=n+1
    for j in range(high-1,low,-1):
        n_list[j][low]=n
        n=n+1
    low=low+1
    high=high-1
    
for i in range(num):
    for y in range(num):
        print(n_list[i][j],end='\t')
    print()
# Out:
# enter the number of rows and column: 5
# 6	6	6	6	6
# 21	21	21	21	21
# 28	28	28	28	28
# 25	25	25	25	25
# 14	14	14	14	14
