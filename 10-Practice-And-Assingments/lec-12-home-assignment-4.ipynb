# %% [markdown]
# <!-- PY-AI-ML-HEADER -->
# # 📘 Practice & Assignments
# ## 📝 Lec 12 Home Assignment 4
#
# > **Series:** Python for AI/ML &nbsp;|&nbsp; **Author:** Sriyut Singh &nbsp;|&nbsp; **Folder:** `10-practice-and-assignments`
#
# ---
# ### 👇 Code & Output Below

# %% [markdown]
# # this is question 3,Python program to convert Celsius to Fahrenheit

# %%
a=int(input('WRITE THE TEMPRATURE IN CELSIUS: '))
print('your area temprature is',a,'degree celsius')
b=(a*1.8+32)
print('your area tempuature is',b,'degree fahrenheit')
# Out:
# WRITE THE TEMPRATURE IN CELSIUS: 67
# your area temprature is 67 degree celsius
# your area tempuature is 152.60000000000002 degree fahrenheit

# %% [markdown]
# # this is question 4,Python Program to Check Prime Number

# %%
a=int(input('write a number: '))
for i in range(2,a):
    if a%i==0:
        print('not prime')
        break
else:
    print('prime')
# Out:
# write a number: 11
# prime

# %% [markdown]
# # this is question 1,Python program to solve quadratic equation (area of rectangle)

# %%
print('finding area of rectangle')
a=int(input('write the length of rectangle: '))
b=int(input('write the bredth of rectangle: '))
c=(a*b)
print(c,'.sq')
# Out:
# finding area of rectangle
# write the length of rectangle: 55
# write the bredth of rectangle: 77
# 4235 .sq

# %% [markdown]
# # all the prime number

# %%
for i in range(2,101):
    for x in range(2,i):
    if (i%x)==0:
            print(i,'is not a prime number')
            break
    else:
        print(i,'is a prime number')
# Out:
# 2 is a prime number
# 3 is a prime number
# 4 is not a prime number
# 5 is a prime number
# 6 is not a prime number
# 7 is a prime number
# 8 is not a prime number
# 9 is not a prime number
# 10 is not a prime number
# 11 is a prime number
# 12 is not a prime number
# 13 is a prime number
# 14 is not a prime number
# 15 is not a prime number
# 16 is not a prime number
# 17 is a prime number
# 18 is not a prime number
# 19 is a prime number
# 20 is not a prime number
# 21 is not a prime number
# 22 is not a prime number
# 23 is a prime number
# 24 is not a prime number
# 25 is not a prime number
# 26 is not a prime number
# 27 is not a prime number
# 28 is not a prime number
# 29 is a prime number
# 30 is not a prime number
# 31 is a prime number
# 32 is not a prime number
# 33 is not a prime number
# 34 is not a prime number
# 35 is not a prime number
# 36 is not a prime number
# 37 is a prime number
# 38 is not a prime number
# 39 is not a prime number
# 40 is not a prime number
# ...

# %%
num=int(input('enter a number: '))

fac=1

for i in range(1,num+1):
    fac=fac * i
print('factorial of',num,'is',fac)
#in factorial we muntiply first with 1 then 2 3 4 5.
# Out:
# enter a number: 10
# factorial of 10 is 3628800

# %%
a=2
b=3
a,b=b,a
print(a)
print(b)
# Out:
# 3
# 2
