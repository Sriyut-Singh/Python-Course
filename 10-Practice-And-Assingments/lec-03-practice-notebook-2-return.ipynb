# %% [markdown]
# <!-- PY-AI-ML-HEADER -->
# # 📘 Practice & Assignments
# ## 📝 Lec 03 Practice Notebook 2 Return
#
# > **Series:** Python for AI/ML &nbsp;|&nbsp; **Author:** Sriyut Singh &nbsp;|&nbsp; **Folder:** `10-practice-and-assignments`
#
# ---
# ### 👇 Code & Output Below

# %% [markdown]
# # PRACTICING FILE

# %%
print('welocome to the bank')
na='sriyut'
ba=100000
pa=1408
na1=input('WRITE YOUR ID: ')
pa1=int(input('WRITE THE PIN: '))
if na1!=na or pa1!=pa:
    print('Provide the correct correct pin or name')
if na1==na and pa1==pa:
    print('It is a macth in system')
    print('YOU HAVE FOUR OPTIONS TO DO \n1.CHECK BALANCE \n2.WITHDRAW AMOUNT \n3.DEPOSIT MONEY \n4.QUIT/DONT WANT TO DO ANYTHING')
    while True:
        op=int(input('write the number about what do you want to do: '))
        if op==1:
            print(ba)
        if op==2:
            wd=int(input('write the amount to withdraw: '))
            ba=ba-wd
            print('your balance is',ba)
        if op==3:
            da=int(input('write the amount to deposit: '))
            ba=ba+da
            print('your balance is',ba)
        if op==4:
            print('thanks for using bank ')
            break
# Out:
# welocome to the bank
# WRITE YOUR ID: sriyut
# WRITE THE PIN: 1408
# It is a macth in system
# YOU HAVE FOUR OPTIONS TO DO
# 1.CHECK BALANCE
# 2.WITHDRAW AMOUNT
# 3.DEPOSIT MONEY
# 4.QUIT/DONT WANT TO DO ANYTHING
# write the number about what do you want to do: 1
# 100000
# write the number about what do you want to do: 2
# write the amount to withdraw: 50000
# your balance is 50000
# write the number about what do you want to do: 3
# write the amount to deposit: 200000
# your balance is 250000
# write the number about what do you want to do: 4
# thanks for using bank

# %%
print('welcome to table game')
ta=int(input('write the number which table you want: '))
for i in range(1,11):
    tab=ta*i
    print(tab)
# Out:
# welcome to table game
# write the number which table you want: 120
# 120
# 240
# 360
# 480
# 600
# 720
# 840
# 960
# 1080
# 1200

# %%
print('welcome to raise to the power game')
a=int(input('write the number which raise to the power you want: '))
b=int(input('write the power in number: '))
for i in range(1):
    a=a**b
    print(a)
# Out:
# welcome to raise to the power game
# write the number which raise to the power you want: 9
# write the power in number: 9
# 387420489

# %%
num1 = int(input('WRITE THE FIRST NUMBER: '))
num2 = int(input('WRITE THE SECOND NUMBER: '))
num4 = int(input('WRITE THE THIRD NUMBER: '))
max1=0 #empty int for max number
if(num1 > num2 ):   # Use If condition to find the greatest number among these two.
    max1= num1
else:
    max1= num2
for i in range(1):
    if (max1 % num1!=0 or max1 % num2!=0 or max1 % num4!=0):
        num3=num1*num2*num4
        print('THE LCM IS',num3)
        break
for x in range(1):
    if(max1 % num1 == 0 and max1 % num2 == 0 and max1 % num4==0):   
        print('THE LCM IS',max1)
        break;
        max1= max1+ 1
# Out:
# WRITE THE FIRST NUMBER: 3
# WRITE THE SECOND NUMBER: 4
# WRITE THE THIRD NUMBER: 5
# THE LCM IS 60

# %% [markdown]
# # SIMPLE INTREST

# %% [markdown]
# ### BUT FOR ONLY 2 YEARS

# %%
def simple_intrest(a,b,x=2):
    print('the time is ',x)
    return (a*b*x)/100
p = float(input('enter the principle amount? '))
r = float(input('enter the rate of intrest? '))
print('simple intrest: ',simple_intrest(a=p,b=r))
# Out:
# enter the principle amount? 2
# enter the rate of intrest? 3
# the time is  2
# simple intrest:  0.12

# %%
print('dal'+' bat')
# Out:
# dal bat

# %%
print('is there any repaire or something else also ')
print('if yes write 1')
print('if no write 2')
r=int(input(('write yes or no')))
c=int(input('write the cost price: '))
s=int(input('write the selling price: '))
if r==1:
    r1=int(input('write the repair cost: '))
    c=r1+c
elif r==2:
    print('ok no problem')
if s<c:
    l=c-s
    lp=l/c*100
    print('LOSS IS',l)
    print('LOSS PERCENT IS',lp,'%')
if c<s:
    p=s-c
    pp=p/c*100
    print('PROFIT IS',p)
    print('PROFIT PERCENT IS',pp,'%')
# Out:
# is there any repaire or something else also
# if yes write 1
# if no write 2
# write yes or no2
# write the cost price: 1200
# write the selling price: 1800
# ok no problem
# PROFIT IS 600
# PROFIT PERCENT IS 50.0 %

# %%
a=int(input('write the C.P: '))

print('first write that your prcent is in loss or in profit')

print('if in loss write 1')

print('if in profit write 2')

b=int(input('write 1 or 2: '))

if b==1 or b==2:
    
    d=int(input('write the profit or loss percent: '))

if b==1:

    c=d/100*a
    
    c=a-c
    
    print('S.P IS',c)

if b==2:

    e=d/100*a
    
    e=e+a
    
    print('S.P IS ',e)
# Out:
# write the C.P: 2000
# first write that your prcent is in loss or in profit
# if in loss write 1
# if in profit write 2
# write 1 or 2: 2
# write the profit or loss percent: 200
# S.P IS  6000.0

# %%
print('THE DATE IS 30 JAN 2021')
# Out:
# THE DATE IS 30 JAN 2021

# %%
print('AFTER THIS THE NEW WORK WILL BEGAN')
# Out:
# AFTER THIS THE NEW WORK WILL BEGAN
