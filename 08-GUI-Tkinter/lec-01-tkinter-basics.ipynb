# %% [markdown]
# <!-- PY-AI-ML-HEADER -->
# # 📘 GUI with Tkinter
# ## 📝 Lec 01 Tkinter Basics
#
# > **Series:** Python for AI/ML &nbsp;|&nbsp; **Author:** Sriyut Singh &nbsp;|&nbsp; **Folder:** `08-gui-tkinter`
#
# ---
# ### 👇 Code & Output Below

# %%
import tkinter

window=tkinter.Tk()
window.title('CALCULATOR')#title
label= tkinter.Label(window, text='HELLO').pack()#to show in window
window.mainloop()

# %%
from tkinter import *
window=Tk()
window.title("calculator")
label = Label(window, text="Hello world!") #creating
label.pack() #showing on screen
a = Label(window, text='Hi world')
a.pack()
b = Label(window, text='python program')
b.pack()
window.mainloop()

# %%
from tkinter import *
window=Tk()
window.title("GUI")
a = Label(window, text="hello world!") #creating
a.grid(column=0, row=0) #showing on screen
b = Label(window, text="Hi world") #creating
b.grid(column=1, row=1)
c = Label(window, text="python program") #creating
c.grid(column=2, row=2)
window.mainloop()

# %%
from tkinter import *
window=Tk()
window.title("GUI")
a = Label(window, text="hello world!") #creating
a.place(x=0, y=0) #showing on screen
b = Label(window, text="Hi world") #creating
b.place(x=50, y=50)
c = Label(window, text="python program") #creating
c.place(x=100, y=100)
window.mainloop()

# %%
from tkinter import *
window=Tk()
window.title("GUI")
a = Label(window, text="hello world!") #creating
a.place(x=0, y=0) #showing on screen
b = Label(window, text="Hi world") #creating
b.place(x=50, y=50)
c = Label(window, text="python program") #creating
c.place(x=100, y=100)
window.mainloop()

# %%
from tkinter import *
window=Tk()
window.title("Label")
l1=Label(window,text="Vishal sir!",font=("ArialBold",50)) #label format
window.geometry("1000x2000") #set window
l1.grid(column=0, row=0) 
window.mainloop()

# %% [markdown]
# # BUTTON

# %%
from tkinter import*
a=Tk()
a.title('Sriyut Program')
c=Label(a,text='Sriyut',font=('bold',50))
b=Button(a,text='PRINT',bg='red',fg='orange')
c.grid(column=0,row=0)
b.grid(column=1,row=1)
a.geometry('300x300')

a.mainloop()

# %%
a=Tk()
a.title('Sriyut Program')
def clicked():
    c=Label(a,text='king',font=('bold',50))
    c.pack()

b1=Button(a,text='PRINT',bg='red',fg='orange',command=clicked)
b1.pack()
a.mainloop()

# %%
a=Tk()
a.title('SRIYUT')

b1=Button(a,text='ENTER',state=DISABLED)
b1.pack()


c1=Button(a,text='Accept policy')
c1.pack()

a.mainloop()

# %% [markdown]
# # Button fuctions

# %%
window=Tk()
window.title("button")

b1=Button(window,text="enter",bg='red',fg='blue',padx=500 ,pady=100) #padding
b1.pack()
window.mainloop()

# %%
from tkinter import *
a=Tk()
a.title('Enter')

txt=Label(a,text= 'Name: ')
b = Entry(a,width=20)
b.grid(column=1,row=0)
txt.grid(column=0,row=0)

def c():
    res='Welcome to WINDOW ' + b.get()
    l1=Label(a,text=res)
    l1.grid(column=1,row=3)
    
b1=Button(a,text='enter',command=c).grid(column=2,row=1)
a.mainloop()

# %%
from tkinter import *
a=Tk()
a.title('Form')
l='sriyut'
h='king'
a.geometry('200x200')
txt=Label(a,text= 'Name: ',bg='green',fg='blue')
txt.grid(column=0,row=0)
c = Entry(a,width=20)
c.grid(column=1,row=0)
txt2=Label(a,text='Password: ',bg='black',fg='white')
txt2.grid(column=0,row=1)
e= Entry(a,width=20)
e.grid(column=1,row=1)
def s():
    res='Welcome to WINDOW ' + c.get()
    l1=Label(a,text=res)
    l1.grid(column=1,row=3)
b1=Button(a,text='enter',bg='orange',fg='red').grid(column=1,row=2)
if l==str(c.get()) and h==str(e.get()):
    command=s
a.mainloop()

# %%
from tkinter import *
s= Tk()
s.title('sum')
s.geometry('200x200')
txt=Label(s,text= 'Num 1: ',bg='green',fg='blue')
txt.grid(column=0,row=0)
c = Entry(s,width=20)
c.grid(column=1,row=0)
txt2=Label(s,text='Num 2: ',bg='black',fg='white')
txt2.grid(column=0,row=1)
e= Entry(s,width=20)
e.grid(column=1,row=1)
def sum1():
    add= int(c.get()) + int(e.get())
    k=Label(s,text=add).grid(column=1,row=4)
b1=Button(s,text='Sum',bg='orange',fg='red',command=sum1).grid(column=1,row=2)
s.mainloop()

# %%
from tkinter import *
a=1000000
int(a)
k= Tk()
k.title('LOGIN')
l='sriyut'
h='king'
k.geometry('400x200')
txt=Label(k,text= 'Name: ',bg='green',fg='blue')
txt.grid(column=0,row=0)
c = Entry(k,width=20)
c.grid(column=1,row=0)
txt2=Label(k,text='Password: ',bg='black',fg='white')
txt2.grid(column=0,row=1)
e= Entry(k,width=20)
e.grid(column=1,row=1)

def check():
    res='Welcome to A.T.M ' + c.get()
    ers='provide correct information'
    if c.get() == l and e.get()==h:
        l1=Label(k,text=res)
        l1.grid(column=1,row=3)
        def sub():
            b=int(t2.get())
            c=a-b
            t3.insert(0,c)
    
        def button_clear():
            t3.delete(0, END)
        
        win=Tk()
        win.geometry('250x250')


        l2=Label(win,text="withraw amount")
        l2.grid(row=1,column=0)
        t2=Entry(win)
        t2.grid(row=1,column=1)

        l3=Label(win,text="Left amount")
        l3.grid(row=2,column=0)
        t3=Entry(win)
        t3.grid(row=2,column=1)

        b1=Button(win,text="Click For withdraw",command=sub)
        b1.grid(row=3,column=0)

        b2=Button(win,text="Clear",command=button_clear)
        b2.grid(row=3,column=1)

        if c.get() != l or e.get()!=h:
            l2=Label(k,text=ers)
            l2.grid(column=1,row=4)
            
k.mainloop()

# %%
from tkinter import *
a=1000000
int(a)
k= Tk()
k.title('LOGIN')
l='sriyut'
h='king'
k.geometry('400x200')
txt=Label(k,text= 'Name: ',bg='green',fg='blue')
txt.grid(column=0,row=0)
c = Entry(k,width=20)
c.grid(column=1,row=0)
txt2=Label(k,text='Password: ',bg='black',fg='white')
txt2.grid(column=0,row=1)
e= Entry(k,width=20)
e.grid(column=1,row=1)
def check():
    res='Welcome to A.T.M ' + c.get()
    ers='provide correct information'
    if c.get() == l and e.get()==h:
        l1=Label(k,text=res)
        l1.grid(column=1,row=3)
    else:
        l2=Label(k,text=ers)
        l2.grid(column=1,row=4)
b1=Button(k,text='enter',bg='orange',fg='red',command=check).grid(column=1,row=2) 
k.mainloop()

# %%
from tkinter import *
def sub():
        b=int(t2.get())
        c=a-b
        t3.insert(0,c)
    
def button_clear():
        t3.delete(0, END) 
            
win=Tk()
win.geometry('250x250')


l2=Label(win,text="withraw amount")
l2.grid(row=1,column=0)
t2=Entry(win)
t2.grid(row=1,column=1)

l3=Label(win,text="Left amount")
l3.grid(row=2,column=0)
t3=Entry(win)
t3.grid(row=2,column=1)

b1=Button(win,text="Click For withdraw",command=sub)
b1.grid(row=3,column=0)

b2=Button(win,text="Clear",command=button_clear)
b2.grid(row=3,column=1)
 
win.mainloop()

# %%
from tkinter import *
a=1000000
int(a)
k= Tk()
k.title('LOGIN')
l='sriyut'
h='king'
k.geometry('400x200')
txt=Label(k,text= 'Name: ',bg='green',fg='blue')
txt.grid(column=0,row=0)
c = Entry(k,width=20)
c.grid(column=1,row=0)
txt2=Label(k,text='Password: ',bg='black',fg='white')
txt2.grid(column=0,row=1)
e= Entry(k,width=20)
e.grid(column=1,row=1)
def check():
    res='  Welcome to A.T.M  ' + c.get()
    ers='Provide correct information'
    if c.get() == l and e.get()==h:
        l1=Label(k,text=res)
        l1.grid(column=1,row=3)
        def sub():
            b=int(t2.get())
            c=a-b
            t3.insert(0,c)
    
        def button_clear():
            t3.delete(0, END) 
            
        win=Tk()
        win.title('A.T.M')
        win.geometry('250x250')


        l2=Label(win,text="withraw amount")
        l2.grid(row=1,column=0)
        t2=Entry(win)
        t2.grid(row=1,column=1)

        l3=Label(win,text="Left amount")
        l3.grid(row=2,column=0)
        t3=Entry(win)
        t3.grid(row=2,column=1)

        b1=Button(win,text="Click For withdraw",command=sub)
        b1.grid(row=3,column=0)

        b2=Button(win,text="Clear",command=button_clear)
        b2.grid(row=3,column=1)
        
        win.mainloop()
    else:
        l2=Label(k,text=ers)
        l2.grid(column=1,row=3)
b1=Button(k,text='enter',bg='orange',fg='red',command=check).grid(column=1,row=2)           
k.mainloop()

# %%
from tkinter import *
from PIL import ImageTk ,Image

base = Tk()
base.title('Start Button')
base.iconbitmap("D:/downloads/Ro .ico")
img=ImageTk.PhotoImage(Image.open ("C:/Ro1.png"))
lab=Label(image=img)
lab.pack()

base.mainloop()

# %%
from tkinter import *
window = Tk()
window.title('Frame')

frame= LabelFrame(window,text='this is a frame',padx=50,pady=50)
frame.pack(padx=40, pady=20)

b = Button(frame, text='Do not Click here!')
b2 = Button(frame, text='...or here!')
b.grid(row=0 , column=0)
b2.grid(row=1, column=1)

window.mainloop()

# %%
import tkinter
window = tkinter.Tk()
window.title("frame")
# creating 2 frames TOP and BOTTOM
top_frame = tkinter.Frame(window).pack()
bottom_frame = tkinter.Frame(window).pack(side = "bottom")
# now, create some widgets in the top_frame and bottom_frame
btn1 = tkinter.Button(top_frame, text = "Button1", fg = "red").pack()# 'fg - foreground' is used to color the contents
btn2 = tkinter.Button(top_frame, text = "Button2", fg = "green").pack(side= 'bottom')# 'text' is used to write the text on the Button
btn3 = tkinter.Button(bottom_frame, text = "Button3", fg = "purple").pack(side = "left")# 'side' is used to align the widgets
btn4 = tkinter.Button(bottom_frame, text = "Button4", fg = "orange").pack(side = "right")
window.mainloop()

# %%
import tkinter
from tkinter import *
window = tkinter.Tk()
window.title("Radio button")

rad1 = Radiobutton(window, text='Python', value=1)
rad2 = Radiobutton(window, text='Java', value=2)
rad3 = Radiobutton(window, text='Arduino', value=3)
rad1.grid(column=0, row=0)
rad2.grid(column=1, row=0)
rad3.grid(column=2, row=0)
                  
window.mainloop()

# %%
from tkinter import *
from PIL import ImageTk,Image

root = Tk()
root.title('Radio with loop ')


#r = IntVar()
#r.set("2")

TOPPINGS = [
("Pepperoni", "Pepperoni"),
("Cheese", "Cheese"),
("Mushroom", "Mushroom"),
("Onion", "Onion"),
]

pizza = StringVar()
pizza.set("Pepperoni")

for text, topping in TOPPINGS:
    Radiobutton(root, text=text, variable=pizza, value=topping).pack(anchor=W)


def clicked(value):
    myLabel = Label(root, text=value)
    myLabel.pack()
#Radiobutton(root, text="Opti
myButton = Button(root, text="Click Me!", command=lambda: clicked(pizza.get()))
myButton.pack()
mainloop()

# %%
from tkinter import messagebox

window = tkinter.Tk()
window.title("message")
messagebox.showinfo('message box','hello world')
window.mainloop()

# %%
from tkinter import *
root = Tk()
root.geometry("400x400")

# Drop Down Boxes

def show():
    myLabel = Label(root, text=clicked.get()).pack()

options = [
    "Monday", 
     "Tuesday", 
    "Wednesday", 
	"Thursday", 
	"Friday",
	"Saturday",
    "Sunday"
]	

clicked = StringVar() #IntVar()
clicked.set(options[0])

drop = OptionMenu(root, clicked, *options)
drop.pack()

myButton = Button(root, text="Show Selection", command=show).pack()

root.mainloop()

# %%
from tkinter import messagebox
from tkinter import *
a=1000000
int(a)
k= Tk()
k.title('LOGIN')
l='sriyut'
h='king'
k.geometry('400x200')
txt=Label(k,text= 'Name: ',bg='green',fg='blue')
txt.grid(column=0,row=0)
c = Entry(k,width=20)
c.grid(column=1,row=0)
txt2=Label(k,text='Password: ',bg='black',fg='white')
txt2.grid(column=0,row=1)
e= Entry(k,width=20)
e.grid(column=1,row=1)
def check():
    res='  Welcome to A.T.M  ' + c.get()
    ers='Provide correct information'
    if c.get() == l and e.get()==h:
        l1=Label(k,text=res)
        l1.grid(column=1,row=3)
        def sub():
            b=int(t2.get())
            c=a-b
            t3.insert(0,c)
    
        def button_clear():
            t3.delete(0, END)
            
        def add():
            d=int(t4.get())
            c=a+d
            t3.insert(0,c)
        
        win=Tk()
        win.title('A.T.M')
        win.geometry('350x300')


        l2=Label(win,text="withraw amount")
        l2.grid(row=1,column=0)
        t2=Entry(win)
        t2.grid(row=1,column=1)

        l3=Label(win,text="Left amount")
        l3.grid(row=7,column=0)
        t3=Entry(win)
        t3.grid(row=7,column=1)
        
        
        l4=Label(win,text="Deposit amount")
        l4.grid(row=4,column=0)
        t4=Entry(win)
        t4.grid(row=4,column=1)

        b1=Button(win,text="Click For withdraw",command=sub)
        b1.grid(row=8,column=0)

        b3=Button(win,text="Click For deposite",command=add)
        b3.grid(row=9,column=0)
        
        b2=Button(win,text="Clear",command=button_clear)
        b2.grid(row=7,column=2)
        
        win.mainloop()
    else:
        window = tkinter.Tk()
        messagebox.showinfo('invalid user',ers)
        window.mainloop()
b1=Button(k,text='enter',bg='orange',fg='red',command=check).grid(column=1,row=2)           
k.mainloop()

# %%
from tkinter import messagebox
from tkinter import *
import tkinter
a=1000000
k= Tk()
k.title('LOGIN')
l='sriyut'
h='king'
k.geometry('400x200')
txt=Label(k,text= 'Name: ',bg='green',fg='blue')
txt.grid(column=0,row=0)
c = Entry(k,width=20)
c.grid(column=1,row=0)
txt2=Label(k,text='Password: ',bg='black',fg='white')
txt2.grid(column=0,row=1)
e= Entry(k,width=20)
e.grid(column=1,row=1)
def check():
    a=1000000
    res='  Welcome to A.T.M  ' + c.get()
    ers='Provide correct information'
    if c.get() == l and e.get()==h:
        l1=Label(k,text=res)
        l1.grid(column=1,row=3)
        def sub():
            b=int(t2.get())
            a=a-b
            t3.insert(0,a)
    
        def button_clear():
            t3.delete(0, END)
            
        def add():
            d=int(t4.get())
            
            a=a+d
            t3.insert(0,a)
        
        def balance():
            t3.insert(0,a)
        
        win=Tk()
        win.title('A.T.M')
        win.geometry('350x300')


        l2=Label(win,text="withraw amount")
        l2.grid(row=1,column=0)
        t2=Entry(win)
        t2.grid(row=1,column=1)

        l3=Label(win,text="Left amount")
        l3.grid(row=7,column=0)
        t3=Entry(win)
        t3.grid(row=7,column=1)
        
        
        l4=Label(win,text="Deposit amount")
        l4.grid(row=4,column=0)
        t4=Entry(win)
        t4.grid(row=4,column=1)

        b1=Button(win,text="Click For withdraw",command=sub)
        b1.grid(row=8,column=0)

        b3=Button(win,text="Click For deposite",command=add)
        b3.grid(row=9,column=0)
        
        b4=Button(win,text="Click For Balance",command=balance)
        b4.grid(row=10,column=0)
        
        b2=Button(win,text="Clear",command=button_clear)
        b2.grid(row=7,column=2)
        
        win.mainloop()
    else:
        window = tkinter.Tk()
        messagebox.showerror('invalid user',ers)
        window.mainloop()
b1=Button(k,text='enter',bg='orange',fg='red',command=check).grid(column=1,row=2)           
k.mainloop()

# %%
#Checkbutton Widget:
import tkinter
from tkinter import *
window = tkinter.Tk()
window.title("checkbutton")
chk_state = BooleanVar()
chk_state.set (False)
chk = Checkbutton(window, text='select', var=chk_state)
chk.grid(column=0, row=0)
mainloop()

# %%
#Spinbox weight:
import tkinter
from tkinter import scrolledtext
window = Tk()
spin = Spinbox(window, from_=0, to=1000, width=15, increment=5).pack()
mainloop()

# %%
import tkinter
from tkinter import*
from PIL import ImageTk,Image
from tkinter import filedialog
root=Tk()
root.geometry('400x400')
root.title('Button worker')
def open():
    global my_image
    root.filename = filedialog.askopenfilename(initialdir="S:/", title="Select A File", filetypes=(("jpg files", "*.jpg"),('png files','*.png'),('pdf files','*.pdf'),("all files", "*.*")))
    my_label = Label(root, text=root.filename).pack()
    my_image = ImageTk.PhotoImage(Image.open(root.filename))
    my_image_label = Label(image=my_image).pack()
    #icon = 
my_btn = Button(root, text="Click here to Open File", command=open).pack()
root.mainloop()
