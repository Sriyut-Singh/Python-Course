# %% [markdown]
# <!-- PY-AI-ML-HEADER -->
# # 📘 GUI with Tkinter
# ## 📝 Lec 07 Tkinter Messagebox
#
# > **Series:** Python for AI/ML &nbsp;|&nbsp; **Author:** Sriyut Singh &nbsp;|&nbsp; **Folder:** `08-gui-tkinter`
#
# ---
# ### 👇 Code & Output Below

# %%
from tkinter import messagebox
import tkinter
window = tkinter.Tk()
window.title("message")
messagebox.showwarning('message box','hello world')
window.mainloop()
