# %% [markdown]
# <!-- PY-AI-ML-HEADER -->
# # 📘 Data Structures
# ## 📝 Lec 02 Tuple
#
# > **Series:** Python for AI/ML &nbsp;|&nbsp; **Author:** Sriyut Singh &nbsp;|&nbsp; **Folder:** `02-data-structures`
#
# ---
# ### 👇 Code & Output Below

# %% [markdown]
# # tuple
#
# # tuple is imutable use circular breacket

# %%
mytuple=(1,2,3,4,'hello')
print(mytuple)
type(mytuple)
# Out:
# (1, 2, 3, 4, 'hello')
# tuple

# %%
print(mytuple[4])#indexing in tuple
# Out:
# hello

# %%
myList1=[1,2,3,4,5,3,3,6,7,8,10]
myList1[1:4]#slicing
# Out:
# [2, 3, 4]

# %%
#empty tuple
et=(1,)#use comma to make it a tuple
type(et)#but because of only one element
# Out:
# tuple

# %%
for i in myList1:
    print('yo')
# Out:
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo
# yo

# %%
t= tuple(input('enter tuple: '))
print(t)
# Out:
# enter tuple: 56
# ('5', '6')

# %%
a=()
dir(a)#there are only two function in tuple
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
#deliting tuple
del(myList1)

# %%
l=[]
b=()
for i in range(2):
    aa=input('write: ')
# Out:
# write: 5
# write: 6

# %%
a=tuple(b)
a
# Out:
# ()

# %%
g=(1,2,3,4,5,6,7,8)
print(g.index(1))
print(g)
# Out:
# 0
# (1, 2, 3, 4, 5, 6, 7, 8)

# %%
print('hi')
# Out:
# hi
