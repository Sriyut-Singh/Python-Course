# %% [markdown]
# <!-- PY-AI-ML-HEADER -->
# # 📘 Data Structures
# ## 📝 Lec 05 Slicing
#
# > **Series:** Python for AI/ML &nbsp;|&nbsp; **Author:** Sriyut Singh &nbsp;|&nbsp; **Folder:** `02-data-structures`
#
# ---
# ### 👇 Code & Output Below

# %% [markdown]
# # slicing
#
# # note:here the second value after":" is subtracted by '1'.string concatenation

# %%
s='hy my name is sriyut'

len(s)
# Out:
# 20

# %%
s[4:15]
# Out:
# 'y name is s'

# %%
s[4:15:5]
# Out:
# 'yes'

# %%
s[:]
# Out:
# 'hy my name is sriyut'

# %% [markdown]
# #  negative slicing

# %%
s[-1]
# Out:
# 't'

# %%
s[:--1]
# Out:
# 'h'

# %%
s[-10:-1]
# Out:
# ' is sriyu'

# %%
r='sriyut kumar'

len(r)
# Out:
# 12

# %%
r[0:8:7]
# Out:
# 'sk'

# %%
s[::-1]
# Out:
# 'tuyirs si eman ym yh'

# %%
s[15:5:-1]
# Out:
# 'rs si eman'

# %%
#we can use comma to seperate string and numbers in print('sriyut',2) function 

a=2

print(a,"2")

print('my name is sriyut\n i study in' ,7, 'class')
# Out:
# 2 2
# my name is sriyut
#  i study in 7 class

# %%
#end function also have \n

print('hello', end='' 'world')
# Out:
# helloworld

# %%
print('sriyut\n kumar')
# Out:
# sriyut
#  kumar

# %%
print('sriyut',end='' 'world')
# Out:
# sriyutworld

# %%
print('sriyut', 'kumar', sep='-')
# Out:
# sriyut-kumar

# %%
r='sriyut kumar'

dir(r)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
r.upper()
# Out:
# 'SRIYUT KUMAR'

# %%
r.lower()
# Out:
# 'sriyut kumar'

# %%
r.title()
# Out:
# 'Sriyut Kumar'

# %% [markdown]
# # Split will remove the letter

# %%
s.split()
# Out:
# ['hy', 'my', 'name', 'is', 'sriyut']

# %%
s.split('h')
# Out:
# ['', 'y my name is sriyut']

# %%
s.replace('y','thiseeee')
# It will replace the leter with the letter which you will give
# Out:
# 'hthiseeee mthiseeee name is srithiseeeeut'

# %%
# It will fing the highest index position of the letter or word 
s.rfind('e')
# Out:
# 9
