# %% [markdown]
# <!-- PY-AI-ML-HEADER -->
# # 📘 Data Structures
# ## 📝 Lec 06 Slicing Task
#
# > **Series:** Python for AI/ML &nbsp;|&nbsp; **Author:** Sriyut Singh &nbsp;|&nbsp; **Folder:** `02-data-structures`
#
# ---
# ### 👇 Code & Output Below

# %% [markdown]
# # SLICING means to cut a string to any two parts

# %% [markdown]
# # EXAMPLES ARE GIVEN BELOW

# %%
s='sriyut kumar'

# %%
s
# Out:
# 'sriyut kumar'

# %% [markdown]
# # SLICING

# %%
s[:6]
# Out:
# 'sriyut'

# %%
s[7:]
# Out:
# 'kumar'

# %%
s[0:7]
# Out:
# 'sriyut '

# %%
s[0:6:2]
# Out:
# 'siu'

# %%
s[::-1]
# Out:
# 'ramuk tuyirs'
