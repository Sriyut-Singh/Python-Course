# %% [markdown]
# <!-- PY-AI-ML-HEADER -->
# # 📘 NumPy & Pandas
# ## 📝 Lec 03 Numpy Misc Practice
#
# > **Series:** Python for AI/ML &nbsp;|&nbsp; **Author:** Sriyut Singh &nbsp;|&nbsp; **Folder:** `05-numpy-and-pandas`
#
# ---
# ### 👇 Code & Output Below

# %%
import numpy as n
a = n.diag([6,12,18,24])

# %%
print(a)
# Out:
# [[ 6  0  0  0]
#  [ 0 12  0  0]
#  [ 0  0 18  0]
#  [ 0  0  0 24]]

# %%
a[2],[1]
# Out:
# (array([ 0,  0, 18,  0]), [1])

# %%
2+3
# Out:
# 5

# %%
a= n.arange(1)
# %timeit [5*55+666-555/33+2222]
# Out:
# 78.3 ns ± 0.695 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
6/5
# Out:
# 1.2

# %%
2*5
# Out:
# 10

# %%
1.2+10
# Out:
# 11.2
