# %% [markdown]
# <!-- PY-AI-ML-HEADER -->
# # 📘 NumPy & Pandas
# ## 📝 Lec 04 Pandas Practice
#
# > **Series:** Python for AI/ML &nbsp;|&nbsp; **Author:** Sriyut Singh &nbsp;|&nbsp; **Folder:** `05-numpy-and-pandas`
#
# ---
# ### 👇 Code & Output Below

# %%
import numpy as np

import pandas as pd

s = pd.Series([1,3,5, np.nan,6,8])

s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
import numpy as np

import pandas as pd

dates = pd.date_range('20210101', periods=6)

dates
# Out:
# DatetimeIndex(['2021-01-01', '2021-01-02', '2021-01-03', '2021-01-04',
#                '2021-01-05', '2021-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
import numpy as np

import pandas as pd

df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))

df
# Out:
#                    A         B         C         D
# 2021-01-01 -0.392526  1.056545  0.076135  0.674738
# 2021-01-02  1.706451  0.574859  2.224063  0.892439
# 2021-01-03 -0.359073  1.293137  0.950756  0.146476
# 2021-01-04 -1.585948  1.318215  0.261527 -0.488649
# 2021-01-05 -0.101002  0.516083  1.715450 -0.096574
# 2021-01-06 -0.312737 -0.700859 -0.291834 -1.293980

# %%
import numpy as np

import pandas as pd

df2 = pd.DataFrame(
     {
         'A': 1.0,
         'B': pd.Timestamp('20130102'),
         "C": pd.Series(1, index=list(range(4)), dtype="float32"),
         "D": np.array([3] * 4, dtype="int32"),
         "E": pd.Categorical(["test", "train", "test", "train"]),
         "F": "foo",
     }
)

df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %% [markdown]
# df2.<TAB># noqa: E225, E999
#
#     df2.A                  df2.bool
#
#     df2.abs                df2.boxplot
#
#     df2.add                df2.C
#
#     df2.add_prefix         df2.clip
#
#     df2.add_suffix         df2.columns
#
#     df2.align              df2.copy
#
#     df2.all                df2.count
#
#     df2.any                df2.combine
#
#     df2.append             df2.D
#
#     df2.apply              df2.describe
#
#     df2.applymap           df2.diff
#
#     df2.B                  df2.duplicated

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))
ts = ts.cumsum()
ts.plot()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <AxesSubplot:>

# %%
df = pd.DataFrame(
    np.random.randn(1000, 4),
    index=ts.index,
    columns=["A", "B", "C", "D"]) 
df = df.cumsum()
#plt.figure()
df.plot()
#plt.legend(loc='best')
# Out:
# <AxesSubplot:>
