# %% [markdown]
# <!-- PY-AI-ML-HEADER -->
# # 📘 Functions & OOPs
# ## 📝 Lec 01 Functions
#
# > **Series:** Python for AI/ML &nbsp;|&nbsp; **Author:** Sriyut Singh &nbsp;|&nbsp; **Folder:** `03-functions-and-oops`
#
# ---
# ### 👇 Code & Output Below

# %% [markdown]
# # FUNCTIONS
#
# # function is a block of code which we name
#
# # and it occur when i call it the code will occur fully
#
# # to use function we use 'def' function

# %%
def sriyut(arguments):
    #block of code
    return expession

# %%
def sriyut(arguments):
    a=int(input('write your name: '))
    return expession 2
# Out:
#   File "<ipython-input-3-407bebea9fae>", line 3
#     return expession 2
#                      ^
# SyntaxError: invalid syntax

# %%
def king():
    print('This is a simple function')

king()
# Out:
# This is a simple function

# %%
#notes
#function are called by its name in python

# %%
id(king)
#it will show id after we will call it
# Out:
# 506199773536

# %%
def SRIYUT():
    print('NAME:SRIYUT \nAGE:29')

SRIYUT()
# Out:
# NAME:SRIYUT
# AGE:29

# %%
#return function
def sriyut():
    print('NAME:SRIYUT \nAGE:29')
    return 'CLASS:', 7
a=sriyut()
print(a)

type(a)
# Out:
# NAME:SRIYUT
# AGE:29
# ('CLASS:', 7)
# tuple

# %%
#defining function
def sum():
    a = 10
    b = 200
    c = a*b
    return c
#calling sum()function in print statement
print('THE SUM IS :',sum())
# Out:
# THE SUM IS : 2000

# %%
def function_name():
    print('this is a simple function')
    return 2
function_name()
print(function_name())
# Out:
# this is a simple function
# this is a simple function
# 2

# %%
a=10
b=50
print(a)
print(b)
# Out:
# 10
# 50

# %%
def function_name():
    print('this is a simple function')
    return 2
print(function_name())
print(function_name)

id(function_name)
# Out:
# this is a simple function
# 2
# <function function_name at 0x00000075DBDB9DC0>
# 506199776704

# %%
# PASS

def i():
    pass
i()

# %%
# ARGUMENTS

def myfun(arg):
    print('passed arguments is==>',arg)
myfun('i am a argument')
myfun('vishal sir student sriyut')
# Out:
# passed arguments is==> i am a argument
# passed arguments is==> vishal sir student sriyut

# %%
def func (name):
    print('Hi',name)
func('sriyut')
# Out:
# Hi sriyut

# %%
def sum(a,b):
    return a+b;

# %%
#taking values from the user
a= int(input('enter a: '))
b= int(input('enter b: '))

#printing the sum of a and b
print('addition a+b=',sum(a,b))
def mul(a,b):
    return a*b;
print('multiplication a*b=',mul(a,b))

def div(a,b):
    return a/b;
print('division a/b=',div(a,b))

def sub(a,b):
    return a-b;
print('subtration a-b=',sub(a,b))
# Out:
# enter a: 4
# enter b: 4
# addition a+b= 8
# multiplication a*b= 16
# division a/b= 1.0
# subtration a-b= 0

# %%
def myfun(arg):
    print('passed argument is==>',arg)
myfun('i am a argument')
myfun('sryut')
# Out:
# passed argument is==> i am a argument
# passed argument is==> sryut

# %%
def mufun(name,age,roll,likes):
    print('my name is',name)
    print('my age is',age)
    print('my roll no is',roll)
    print('i like',likes[0],'and',likes[1])
mufun('sriyut',22,12,['python','maths'])
# Out:
# my name is sriyut
# my age is 22
# my roll no is 12
# i like python and maths

# %%
def addthree(num1,num2,num3):#it is called perimeter
    return num1+num2+num3
addition = addthree(5,10,15)#if we call in function argument
print(addition)

addthree(1,2,2)
# Out:
# 30
# 5

# %%
#can also change the value
addition= addthree(222,333,444)

addition
# Out:
# 999

# %%
def cs(str):
    str = str + ' hows you'
    print('printing the string inside function :',str)
s1='hi i am there'

cs(s1)

print('printing the string outside function :',s1)
# Out:
# printing the string inside function : hi i am there hows you
# printing the string outside function : hi i am there

# %%
# types of argument

#required argument
def simple_intrest(a,b,x=2):
    print('the time is ',x)
    return (a*b*x)/100
p = float(input('enter the principle amount? '))
r = float(input('enter the rate of intrest? '))
print('simple intrest: ',simple_intrest(a=p,b=r))
# Out:
# enter the principle amount? 3000
# enter the rate of intrest? 4
# the time is  2
# simple intrest:  240.0

# %%
# default arguments

def p(name,age=13):
    print('my name is',name,'and age is ',age)
p(name = 'sriyut')
# Out:
# my name is sriyut and age is  13

# %%
# VARIABLE-LENGTH ARGUMENT

def printme(*name):
    print('type of passed argument is',type(name))
    print('printing the passed arguments...')
    for name in name:
        print(name)
printme('sriyut','mohit','umang')
# Out:
# type of passed argument is <class 'tuple'>
# printing the passed arguments...
# sriyut
# mohit
# umang

# %%
def allnum(*num):
    print('the addition of all numbers is')
    return num[0]+num[1]+num[2]+num[3]+num[4]+num[5]
allnum(1,2,3,4,5,6)
# Out:
# the addition of all numbers is
# 21

# %%
def addAll(*args):
    result = 0
    for x in args:
        result = result + x
    return result
print("Sum is", addAll(1, 2, 3, 4, 5))
# Out:
# Sum is 15

# %%
# KEYWORD ARGUMENT
def intrest(p,r,t):
    return (p*r*t)/100
print('Simple intrest is :',intrest(t=10,r=10,p=1900))
#if we will write a variable is by keywalue then after that all element should be in key value pair
# Out:
# Simple intrest is : 1900.0

# %%
# Lambda function

x= lambda y : y * 2
print(x(5))
x(3)
# Out:
# 10
# 6

# %%
a = lambda x,y,z : x + y * z + 2
print(a(5,10,33))
# Out:
# 337

# %%
# IN-BUILT FUNCTION

#DOUBT

op=lambda a,b:a-b
dev=lambda a,b:a/b
def op(a,b):
    print(a-b)
    return a/b
print(op(9,4))
# Out:
# 5
# 2.25

# %%
# IN-BUILT FUNCTION STARTS NOW

# Doc String

def print_name(name):
    '''
    This function prints the name
    '''
    print('hello '+str(name))

print(print_name.__doc__)#print doc string of the function
#have to use '__'before and after the doc word

print_name('sriyut')
# Out:
#     This function prints the name
#
# hello sriyut

# %%
def king(sri):
    '''
    This is SRIYUT 
    '''
    print('hello'+str(sri))

king.__doc__
#shows as the doc is 
#if write enter hen \n if not the not
# Out:
# '\n    This is SRIYUT \n    '

# %%
def king(sri):
    '''This is SRIYUT'''
    print('hello'+str(sri))
king.__doc__

global_var = "This is global variable"

def test_life_time():
    """
    This function test the life time of a variables
    """
    local_var = "This is local variable"
    print(local_var)       #print local variable local_var
    
    print(global_var)      #print global variable global_var

#calling function
test_life_time()
# Out:
# This is local variable
# This is global variable

# %%
#print global variable global_var
print(global_var)

#print local variable local_var
print(local_var)
#it is showing error because local_var is only defined in function only
# Out:
# This is global variable
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-d112718fe5cb> in <module>
#       3
#       4 #print local variable local_var
# ----> 5 print(local_var)
#       6 #it is showing error because local_var is only defined in function only
#
# NameError: name 'local_var' is not defined

# %%
sri='my name is sriyut'
def my():
    global yut
    yut='this is sriyut'
    print(sri)
    print(yut)
    
my()
print(sri)
print(yut)
#use global term to changge local variable to global
# Out:
# my name is sriyut
# this is sriyut
# my name is sriyut
# this is sriyut

# %%
# Built-in Function

#abs()

#find the absolute value

num = -100

print(abs(num))

#only give the value without its sign
# Out:
# 100

# %%
'''all()
return value of all() function

True: if all elements in an iterable are true
False: if any element in an iterable is false 
'''

lst = [1,2,3,4]
print(all(lst))
#cant interate on false and 0
# Out:
# True

# %%
'''
enumerate()
The enumerate() method adds counter to an iterable and returns it

syntax : enumerate(interable, start=0)
'''
numbers = [10,20,30,40]

for index, num in enumerate(numbers):
    print('index {0} has value {1}'.format(index, num))

#can give index position by default by 0
# Out:
# index 0 has value 10
# index 1 has value 20
# index 2 has value 30
# index 3 has value 40

# %%
#divmod()
print(divmod(9, 2)) #print quotient and remainder as a tuple

#try with other number

numbers = [10, 20, 30, 40]

for index, num in enumerate(numbers,15):
    print("index {0} has value {1}".format(index, num))
# Out:
# (4, 1)
# index 15 has value 10
# index 16 has value 20
# index 17 has value 30
# index 18 has value 40

# %%
a= int(input('write the number which factorial you want: '))
for i in range(1,6):
    b=i*a
print(b)
# Out:
# write the number which factorial you want: 10
# 50

# %%
def factorial(num):
    """
    This is a recursive function to find the factorial of a given number
    """
    return 1 if num == 1 else (num * factorial(num-1))

num = 5
print ("Factorial of {0} is {1}".format(num, factorial(num)))
# Out:
# Factorial of 5 is 120

# %% [markdown]
# # Recursion

# %%
def fibonacci(num):
    return num if num <= 1 else fibonacci(num-1) + fibonacci(num-2)

nterms = int(input('write the number: '))
print('fibonacci sequence')
for num in range(nterms):
    print(fibonacci(num))
# Out:
# write the number: 5
# fibonacci sequence
# 0
# 1
# 1
# 2
# 3
