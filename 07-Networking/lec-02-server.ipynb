# %% [markdown]
# <!-- PY-AI-ML-HEADER -->
# # 📘 Networking (Sockets)
# ## 📝 Lec 02 Server
#
# > **Series:** Python for AI/ML &nbsp;|&nbsp; **Author:** Sriyut Singh &nbsp;|&nbsp; **Folder:** `07-networking`
#
# ---
# ### 👇 Code & Output Below

# %%
import socket
s=socket.socket(socket.AF_INET, socket.SOCK_STREAM) #af_inet = adress from internet  #create tcp protocol
s.bind((socket.gethostname(),1236))           
#port number can be anything between 0-65535(we usually specify non-previleged ports which are > 1023)
s.listen(5)
 
while True:
    clt,adr=s.accept()
    print(f"Connection to {adr}established")  
   #f string is literal string prefixed with f which 
   #contains python expressions inside braces
    clt.send(bytes("Socket Programming in Python","utf-8 ")) #to send info to clientsocket
    clt.close()
# Out:
# Connection to ('192.168.43.98', 60798)established
