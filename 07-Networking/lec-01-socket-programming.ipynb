# %% [markdown]
# <!-- PY-AI-ML-HEADER -->
# # 📘 Networking (Sockets)
# ## 📝 Lec 01 Socket Programming
#
# > **Series:** Python for AI/ML &nbsp;|&nbsp; **Author:** Sriyut Singh &nbsp;|&nbsp; **Folder:** `07-networking`
#
# ---
# ### 👇 Code & Output Below

# %%
# To do this open scoket and client file
