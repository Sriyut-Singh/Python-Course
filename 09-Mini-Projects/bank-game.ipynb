# %% [markdown]
# <!-- PY-AI-ML-HEADER -->
# # 📘 Mini Projects
# ## 📝 Bank Game
#
# > **Series:** Python for AI/ML &nbsp;|&nbsp; **Author:** Sriyut Singh &nbsp;|&nbsp; **Folder:** `09-mini-projects`
#
# ---
# ### 👇 Code & Output Below

# %%
a='sriyut'
b=80
e=50000
c=input('write your user name: ')
d=int(input('write the pin: '))
if a==c:
    if b==d:
        print('welcome to A.T.M')
while True:
    if a != c: 
        if b!= d:
            print('pleas provide correct password or pin')
    if a==c:
        if b==d:
            print('there are four option which you can do')
            print('1.check balance')
            print('2.withdraw')
            print('3.deposit')
            print('4.do not want to do any-thing ')
            f=1
            g=2
            h=3
            j=4
            i=int(input('what do you want to do:', ))
            if i==f:
                print('your balance is',e)
            if i==g:
                k=int(input('write the amout to withdraw:'))
                if e>=k:
                       print('you can withdraw')
                else:
                    print('you cant withdraw')
                if e>=k:
                    e=e-k
                    print('your left amount is',e)
            if i==h:
                x=int(input('write the amount to deposit: '))
                e=e+x
                print('your amount is',e)
            if i==j:
                    print('THANK YOU FOR USING A.T.M!!!')
                    break
# Out:
# write your user name: sriyut
# write the pin: 80
# welcome to A.T.M
# there are four option which you can do
# 1.check balance
# 2.withdraw
# 3.deposit
# 4.do not want to do any-thing
# what do you want to do:4
# THANK YOU FOR USING A.T.M!!!

# %%
print(e)
# Out:
# 50000
