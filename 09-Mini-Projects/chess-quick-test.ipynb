# %% [markdown]
# <!-- PY-AI-ML-HEADER -->
# # 📘 Mini Projects
# ## 📝 Chess Quick Test
#
# > **Series:** Python for AI/ML &nbsp;|&nbsp; **Author:** Sriyut Singh &nbsp;|&nbsp; **Folder:** `09-mini-projects`
#
# ---
# ### 👇 Code & Output Below

# %%
import time
a='Mat karo on so i will also not off the laptop'
for i in range(1):
    time.sleep(1)
    print(a)
# Out:
# Mat karo on so i will also not off the laptop

# %%
import chess
board = chess.Board()
board.turn == chess.WHITE
board.push_san('Nh3')
board.push_san('Nf3')
board.push_san('Nc3')
board.push_san('Na3')
board.push_san('h3')
board.push_san('g3')
board.push_san('f3')
board.push_san('e3')
board.push_san('d3')
board.push_san('c3')
board.push_san('b3')
board.push_san('a3')
board.push_san('h4')
board.push_san('g4')
board.push_san('f4')
board.push_san('e4')
board.push_san('e4')
board.push_san('c4')
board.push_san('b4')
board.push_san('a4')
board
board
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-cc2f1e341dda> in <module>
#       3 board.turn == chess.WHITE
#       4 board.push_san('Nh3')
# ----> 5 board.push_san('Nf3')
#       6 board.push_san('Nc3')
#       7 board.push_san('Na3')
#
# E:\anaconda\lib\site-packages\chess\__init__.py in push_san(self, san)
#    3001         :raises: :exc:`ValueError` if neither legal nor a null move.
#    3002         """
# -> 3003         move = self.parse_san(san)
#    3004         self.push(move)
#    3005         return move
#
# E:\anaconda\lib\site-packages\chess\__init__.py in parse_san(self, san)
#    2988
#    2989         if not matched_move:
# -> 2990             raise ValueError(f"illegal san: {san!r} in {self.fen()}")
#    2991
#    2992         return matched_move
#
# ValueError: illegal san: 'Nf3' in rnbqkbnr/pppppppp/8/8/8/7N/PPPPPPPP/RNBQKB1R b KQkq - 1 1
